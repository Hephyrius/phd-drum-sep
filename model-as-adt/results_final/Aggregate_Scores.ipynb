# %%
import pandas as pd
import numpy as np

# %%
names = ['hd_epoch_280','trans_epoch_280','conv_epoch_200']
for n in names:
    df = pd.read_csv(f"./{n}.csv")
    for drum in range(5):
        print('=================================')
        print(f'model: {n} drum: {drum}')
        
        d0 = df[df['drum'] == str(drum)]
        d0 = d0.drop(['track_name', 'Unnamed: 0', 'slice', 'drum'], axis=1).mean()
        print(d0)
# Out:
# =================================
# model: hd_epoch_280 drum: 0
# recall       0.784155
# precision    0.807379
# f1           0.785299
# jaccard      0.700984
# accuracy     0.784155
# dtype: float64
# =================================
# model: hd_epoch_280 drum: 1
# recall       0.744517
# precision    0.746806
# f1           0.727839
# jaccard      0.626324
# accuracy     0.744517
# dtype: float64
# =================================
# model: hd_epoch_280 drum: 2
# recall       0.796623
# precision    0.828622
# f1           0.788657
# jaccard      0.722875
# accuracy     0.796623
# dtype: float64
# =================================
# model: hd_epoch_280 drum: 3
# recall       0.932808
# precision    1.000000
# f1           0.963453
# jaccard      0.932808
# accuracy     0.932808
# dtype: float64
# =================================
# model: hd_epoch_280 drum: 4
# recall       0.870245
# precision    0.982131
# f1           0.919056
# jaccard      0.863108
# accuracy     0.870245
# dtype: float64
# =================================
# model: trans_epoch_280 drum: 0
# recall       0.774959
# precision    0.804221
# f1           0.782114
# jaccard      0.694511
# accuracy     0.774959
# dtype: float64
# =================================
# model: trans_epoch_280 drum: 1
# recall       0.727287
# precision    0.744939
# f1           0.719196
# jaccard      0.612481
# accuracy     0.727287
# dtype: float64
# =================================
# model: trans_epoch_280 drum: 2
# recall       0.759814
# precision    0.826489
# f1           0.769082
# jaccard      0.689806
# accuracy     0.759814
# dtype: float64
# =================================
# model: trans_epoch_280 drum: 3
# recall       0.887855
# precision    1.000000
# f1           0.936710
# jaccard      0.887855
# accuracy     0.887855
# dtype: float64
# =================================
# model: trans_epoch_280 drum: 4
# recall       0.883004
# precision    0.983428
# f1           0.927299
# jaccard      0.875819
# accuracy     0.883004
# dtype: float64
# =================================
# model: conv_epoch_200 drum: 0
# recall       0.779184
# precision    0.814014
# f1           0.783760
# jaccard      0.694961
# accuracy     0.779184
# dtype: float64
# =================================
# model: conv_epoch_200 drum: 1
# recall       0.648188
# precision    0.756029
# f1           0.664700
# jaccard      0.536817
# accuracy     0.648188
# dtype: float64
# =================================
# model: conv_epoch_200 drum: 2
# recall       0.725084
# precision    0.826278
# f1           0.745982
# jaccard      0.655525
# accuracy     0.725084
# dtype: float64
# =================================
# model: conv_epoch_200 drum: 3
# recall       0.853628
# precision    1.000000
# f1           0.913681
# jaccard      0.853628
# accuracy     0.853628
# dtype: float64
# =================================
# model: conv_epoch_200 drum: 4
# recall       0.824042
# precision    0.984072
# f1           0.886963
# jaccard      0.816550
# accuracy     0.824042
# dtype: float64

# %%
d0 = df[df['drum'] == drum]

# %%
df = pd.read_csv(f"./{n}.csv")

# %%
df[df['drum'] == str(0)]
# Out:
#       Unnamed: 0            track_name  slice drum    recall  precision  \
# 0              0    MusicDelta_80sRock      0    0  0.799955   0.639927
# 6              6    MusicDelta_80sRock      1    0  0.824972   0.680578
# 12            12    MusicDelta_80sRock      2    0  0.824960   0.680560
# 18            18    MusicDelta_80sRock      3    0  0.799955   0.639927
# 24            24    MusicDelta_80sRock      4    0  0.824960   0.680560
# ...          ...                   ...    ...  ...       ...        ...
# 1872        1872  MusicDelta_SwingJazz     21    0  0.675000   0.900121
# 1878        1878   MusicDelta_Zeppelin      0    0  0.832931   0.820913
# 1884        1884   MusicDelta_Zeppelin      1    0  0.742012   0.722172
# 1890        1890   MusicDelta_Zeppelin      2    0  0.764728   0.668447
# 1896        1896   MusicDelta_Zeppelin      3    0  0.745437   0.735441
#
#             f1   jaccard  accuracy
# 0     0.711048  0.639927  0.799955
# 6     0.745851  0.680578  0.824972
# 12    0.745835  0.680560  0.824960
# 18    0.711048  0.639927  0.799955
# 24    0.745835  0.680560  0.824960
# ...        ...       ...       ...
# 1872  0.751768  0.618546  0.675000
# 1878  0.819795  0.716221  0.832931
# 1884  0.730367  0.609132  0.742012
# 1890  0.684062  0.598123  0.764728
# 1896  0.739960  0.615748  0.745437
#
# [317 rows x 9 columns]
